# %%
#import dependencies
import pandas as pd

# %%
#read in raw GNI data and cleaned carbon dataset
raw_GNI = pd.read_excel('../Raw Data/Excel/GNI_by_country_worldbank.xls')
carbon_dataset = pd.read_excel('../Cleaned Datasets/Carbon_justcountries.xlsx')

# %%
#raw_GNI

# %%
df = raw_GNI.drop([0,1]).reset_index(drop=True) #drop first two rows and reset index
df
# Out:
#                      Data Source World Development Indicators  \
# 0                   Country Name                 Country Code
# 1                          Aruba                          ABW
# 2    Africa Eastern and Southern                          AFE
# 3                    Afghanistan                          AFG
# 4     Africa Western and Central                          AFW
# ..                           ...                          ...
# 262                       Kosovo                          XKX
# 263                  Yemen, Rep.                          YEM
# 264                 South Africa                          ZAF
# 265                       Zambia                          ZMB
# 266                     Zimbabwe                          ZWE
#
#                                      Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                Indicator Name  Indicator Code      1960.0
# ...

# %%
df.columns = df.iloc[0]#set first row to header
df = df[1:]#reset df to not include header row as row
df
# Out:
# 0                   Country Name Country Code  \
# 1                          Aruba          ABW
# 2    Africa Eastern and Southern          AFE
# 3                    Afghanistan          AFG
# 4     Africa Western and Central          AFW
# 5                         Angola          AGO
# ..                           ...          ...
# 262                       Kosovo          XKX
# 263                  Yemen, Rep.          YEM
# 264                 South Africa          ZAF
# 265                       Zambia          ZMB
# 266                     Zimbabwe          ZWE
#
# 0                                Indicator Name  Indicator Code  1960.0  \
# 1    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD     NaN
# 2    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD     NaN
# 3    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD     NaN
# 4    GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD     NaN
# ...

# %%
list(df.columns.values)
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  1960.0,
#  1961.0,
#  1962.0,
#  1963.0,
#  1964.0,
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  2018.0,
#  2019.0,
#  2020.0,
#  2021.0]

# %%
values = df['Country Code']
values
# Out:
# 1      ABW
# 2      AFE
# 3      AFG
# 4      AFW
# 5      AGO
#       ...
# 262    XKX
# 263    YEM
# 264    ZAF
# 265    ZMB
# 266    ZWE
# Name: Country Code, Length: 266, dtype: object

# %%
# GNI_data = pd.DataFrame(df, columns=['Country Name','Country Code','2021.0'])
GNI_data = pd.DataFrame(df, columns=['2021.0'])

# %%
GNI_data
# Out:
#      2021.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# ..      ...
# 262     NaN
# 263     NaN
# 264     NaN
# 265     NaN
# 266     NaN
#
# [266 rows x 1 columns]

# %%
print(df['2021.0'])
