# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Methane_CleanData.xlsx')

# %%
df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            AFE                         NaN                  NaN
# 1            AFG                  South Asia           Low income
# 2            AFW                         NaN                  NaN
# 3            AGO          Sub-Saharan Africa  Lower middle income
# 4            ALB       Europe & Central Asia  Upper middle income
# ..           ...                         ...                  ...
# 234          WSM         East Asia & Pacific  Lower middle income
# 235          YEM  Middle East & North Africa           Low income
# 236          ZAF          Sub-Saharan Africa  Upper middle income
# 237          ZMB          Sub-Saharan Africa           Low income
# 238          ZWE          Sub-Saharan Africa  Lower middle income
#
#                     Country Name           1990           1991           1992  \
# 0    Africa Eastern and Southern  320589.996671  321170.003211  326880.001700
# ...

# %%
nan_values = df[df['Region'].isna()]
nan_values
# Out:
#     Country Code Region IncomeGroup  \
# 0            AFE    NaN         NaN
# 2            AFW    NaN         NaN
# 6            ARB    NaN         NaN
# 33           CEB    NaN         NaN
# 45           CSS    NaN         NaN
# 55           EAP    NaN         NaN
# 56           EAR    NaN         NaN
# 57           EAS    NaN         NaN
# 58           ECA    NaN         NaN
# 59           ECS    NaN         NaN
# 62           EMU    NaN         NaN
# 67           EUU    NaN         NaN
# 68           FCS    NaN         NaN
# 85           HIC    NaN         NaN
# 87           HPC    NaN         NaN
# 91           IBD    NaN         NaN
# 92           IBT    NaN         NaN
# 93           IDA    NaN         NaN
# 94           IDB    NaN         NaN
# 96           IDX    NaN         NaN
# 115          LAC    NaN         NaN
# 121          LCN    NaN         NaN
# 122          LDC    NaN         NaN
# 123          LIC    NaN         NaN
# 126          LMC    NaN         NaN
# ...

# %%
#loop through NaN df to get index 
index_list = []
for idx in nan_values.index:
    index_list.append(idx)

# print the resulting list of index values
print(index_list)
# Out:
# [0, 2, 6, 33, 45, 55, 56, 57, 58, 59, 62, 67, 68, 85, 87, 91, 92, 93, 94, 96, 115, 121, 122, 123, 126, 127, 129, 137, 140, 145, 153, 163, 165, 173, 177, 178, 183, 193, 195, 196, 206, 207, 212, 214, 216, 217, 225, 233]

# %%
#remove index column and set index to country code
countries = df.set_index('Country Code')
countries
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# AFE                                  NaN                  NaN
# AFG                           South Asia           Low income
# AFW                                  NaN                  NaN
# AGO                   Sub-Saharan Africa  Lower middle income
# ALB                Europe & Central Asia  Upper middle income
# ...                                  ...                  ...
# WSM                  East Asia & Pacific  Lower middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa           Low income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                              Country Name           1990           1991  \
# Country Code
# AFE           Africa Eastern and Southern  320589.996671  321170.003211
# ...

# %%
countries_final = countries.drop(countries.index [[0, 2, 6, 33, 45, 55, 56, 57, 58, 59, 62, 67, 68, 85, 87, 91, 92, 93, 94, 96, 115, 121, 122, 123, 126, 127, 129, 137, 140, 145, 153, 163, 165, 173, 177, 178, 183, 193, 195, 196, 206, 207, 212, 214, 216, 217, 225, 233]])
countries_final
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# AFG                           South Asia           Low income
# AGO                   Sub-Saharan Africa  Lower middle income
# ALB                Europe & Central Asia  Upper middle income
# AND                Europe & Central Asia          High income
# ARE           Middle East & North Africa          High income
# ...                                  ...                  ...
# WSM                  East Asia & Pacific  Lower middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa           Low income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                       Country Name          1990          1991          1992  \
# Country Code
# AFG                    Afghanistan   6739.999771   7019.999981   7130.000114
# ...

# %%
#export as excel 
countries_final.to_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Methane_justcountries.xlsx')
