# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Carbon Emissions.xls', sheet_name=1)

# %%
df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df_2 = pd.read_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Carbon Emissions.xls', sheet_name=0, header = 3)

# %%
df_2
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  CO2 emissions (kt)
# 1    Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                    Afghanistan          AFG  CO2 emissions (kt)
# 3     Africa Western and Central          AFW  CO2 emissions (kt)
# 4                         Angola          AGO  CO2 emissions (kt)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  CO2 emissions (kt)
# 262                  Yemen, Rep.          YEM  CO2 emissions (kt)
# 263                 South Africa          ZAF  CO2 emissions (kt)
# 264                       Zambia          ZMB  CO2 emissions (kt)
# 265                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...           2012  \
# 0    EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...            NaN
# ...

# %%
#merge df to get incomegroup
merged_df = pd.merge(df, df_2, on='Country Code')
merged_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
#remove unneeded columns 
clean_df = merged_df.drop(['SpecialNotes','TableName','Indicator Name', 'Indicator Code','1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', '2021'], axis=1)
clean_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                     Country Name           1990           1991           1992  \
# 0                          Aruba            NaN            NaN            NaN
# ...

# %%
#get index of NaN rows
nan_values = clean_df[clean_df['1990'].isna()]
nan_values
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 11           ASM         East Asia & Pacific  Upper middle income
# 27           BMU               North America          High income
# 38           CHI       Europe & Central Asia          High income
# 51           CUW   Latin America & Caribbean          High income
# 52           CYM   Latin America & Caribbean          High income
# 69           ERI          Sub-Saharan Africa           Low income
# 78           FRO       Europe & Central Asia          High income
# 79           FSM         East Asia & Pacific  Lower middle income
# 84           GIB       Europe & Central Asia          High income
# 91           GRL       Europe & Central Asia          High income
# 93           GUM         East Asia & Pacific          High income
# 96           HKG         East Asia & Pacific          High income
# ...

# %%
#loop through NaN df to get index 
index_list = []
for idx in nan_values.index:
    index_list.append(idx)

# print the resulting list of index values
print(index_list)
# Out:
# [0, 11, 27, 38, 51, 52, 69, 78, 79, 84, 91, 93, 96, 108, 145, 146, 148, 154, 163, 170, 171, 187, 191, 195, 198, 211, 224, 227, 236, 254, 255, 260]

# %%
#remove index column and set index to country code
clean_df = clean_df.set_index('Country Code')
clean_df
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# ABW            Latin America & Caribbean          High income
# AFE                                  NaN                  NaN
# AFG                           South Asia           Low income
# AFW                                  NaN                  NaN
# AGO                   Sub-Saharan Africa  Lower middle income
# ...                                  ...                  ...
# XKX                Europe & Central Asia  Upper middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa           Low income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                              Country Name           1990           1991  \
# Country Code
# ABW                                 Aruba            NaN            NaN
# ...

# %%
#remove rows with NaN values
carbon_clean = clean_df.drop(clean_df.index [[0, 11, 27, 38, 51, 52, 69, 78, 79, 84, 91, 93, 96, 
                                               108, 145, 146, 148, 154, 163, 170, 171, 187, 191, 
                                               195, 198, 211, 224, 227, 236, 254, 255, 260]])
carbon_clean
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# AFE                                  NaN                  NaN
# AFG                           South Asia           Low income
# AFW                                  NaN                  NaN
# AGO                   Sub-Saharan Africa  Lower middle income
# ALB                Europe & Central Asia  Upper middle income
# ...                                  ...                  ...
# WSM                  East Asia & Pacific  Lower middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa           Low income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                              Country Name           1990           1991  \
# Country Code
# AFE           Africa Eastern and Southern  304354.882669  298735.435602
# ...

# %%
#export as excel 
carbon_clean.to_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Carbon_CleanData.xlsx', index=False)
#export as csv
carbon_clean.to_csv('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Carbon_CleanData.csv')

# %%
#drop region if needed 
carbon_clean.drop('Region', axis=1, inplace=True)
carbon_clean
# Out:
#                       IncomeGroup                 Country Name           1990  \
# Country Code
# AFE                           NaN  Africa Eastern and Southern  304354.882669
# AFG                    Low income                  Afghanistan    2380.000000
# AFW                           NaN   Africa Western and Central   97925.796888
# AGO           Lower middle income                       Angola    6560.000000
# ALB           Upper middle income                      Albania    5980.000000
# ...                           ...                          ...            ...
# WSM           Lower middle income                        Samoa      90.000000
# YEM                    Low income                  Yemen, Rep.    6640.000000
# ZAF           Upper middle income                 South Africa  247660.000000
# ZMB                    Low income                       Zambia    2740.000000
# ZWE           Lower middle income                     Zimbabwe   16540.000000
#
# ...

# %%
#export as excel 
carbon_clean.to_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Carbon_CleanData_noregion.xlsx', index=False)
#export as csv
carbon_clean.to_csv('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Carbon_CleanData_noregion.csv')
