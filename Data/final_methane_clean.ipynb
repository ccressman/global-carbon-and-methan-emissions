# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Methane Emissions.xls', sheet_name=1)

# %%
df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df_2 = pd.read_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Methane Emissions.xls', sheet_name=0, header = 3)

# %%
df_2
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                Indicator Name     Indicator Code  1960  1961  \
# 0    Methane emissions (kt of CO2 equivalent)  EN.ATM.METH.KT.CE   NaN   NaN
# 1    Methane emissions (kt of CO2 equivalent)  EN.ATM.METH.KT.CE   NaN   NaN
# 2    Methane emissions (kt of CO2 equivalent)  EN.ATM.METH.KT.CE   NaN   NaN
# 3    Methane emissions (kt of CO2 equivalent)  EN.ATM.METH.KT.CE   NaN   NaN
# ...

# %%
#merge df to get incomegroup
merged_df = pd.merge(df, df_2, on='Country Code')
merged_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
#remove unneeded columns 
clean_df = merged_df.drop(['SpecialNotes','TableName','Indicator Name', 'Indicator Code','1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '2020', '2021'], axis=1)
clean_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                     Country Name           1990           1991           1992  \
# 0                          Aruba            NaN            NaN            NaN
# ...

# %%
#get index of NaN rows
nan_values = clean_df[clean_df['1990'].isna()]
nan_values
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 11           ASM         East Asia & Pacific  Upper middle income
# 27           BMU               North America          High income
# 38           CHI       Europe & Central Asia          High income
# 51           CUW   Latin America & Caribbean          High income
# 52           CYM   Latin America & Caribbean          High income
# 78           FRO       Europe & Central Asia          High income
# 84           GIB       Europe & Central Asia          High income
# 91           GRL       Europe & Central Asia          High income
# 93           GUM         East Asia & Pacific          High income
# 96           HKG         East Asia & Pacific          High income
# 108          IMN       Europe & Central Asia          High income
# 145          MAC         East Asia & Pacific          High income
# ...

# %%
#remove index to delete rows with NaN data
clean_df = clean_df.set_index('Country Code')
clean_df
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# ABW            Latin America & Caribbean          High income
# AFE                                  NaN                  NaN
# AFG                           South Asia           Low income
# AFW                                  NaN                  NaN
# AGO                   Sub-Saharan Africa  Lower middle income
# ...                                  ...                  ...
# XKX                Europe & Central Asia  Upper middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa           Low income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                              Country Name           1990           1991  \
# Country Code
# ABW                                 Aruba            NaN            NaN
# ...

# %%
methane_clean = clean_df.drop(clean_df.index [[0,11,27,38,51,52,78,84,91,93,96,108,145,146,148,163,171,
                                               191,195,198,211,224,227,254,255,260]])
methane_clean
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# AFE                                  NaN                  NaN
# AFG                           South Asia           Low income
# AFW                                  NaN                  NaN
# AGO                   Sub-Saharan Africa  Lower middle income
# ALB                Europe & Central Asia  Upper middle income
# ...                                  ...                  ...
# WSM                  East Asia & Pacific  Lower middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa           Low income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                              Country Name           1990           1991  \
# Country Code
# AFE           Africa Eastern and Southern  320589.996671  321170.003211
# ...

# %%
#double check to make sure all NaN values removed
nan_values2 = methane_clean[methane_clean['1990'].isna()]
nan_values2
# Out:
# Empty DataFrame
# Columns: [Region, IncomeGroup, Country Name, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# Index: []
#
# [0 rows x 33 columns]

# %%
methane_clean
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# AFE                                  NaN                  NaN
# AFG                           South Asia           Low income
# AFW                                  NaN                  NaN
# AGO                   Sub-Saharan Africa  Lower middle income
# ALB                Europe & Central Asia  Upper middle income
# ...                                  ...                  ...
# WSM                  East Asia & Pacific  Lower middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa           Low income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                              Country Name           1990           1991  \
# Country Code
# AFE           Africa Eastern and Southern  320589.996671  321170.003211
# ...

# %%
#export as excel 
methane_clean.to_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Methane_CleanData.xlsx', index=False)
#export as csv
methane_clean.to_csv('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Methane_CleanData.csv')

# %%
#drop region if needed 
methane_clean.drop('Region', axis=1, inplace=True)
methane_clean
# Out:
#                       IncomeGroup                 Country Name           1990  \
# Country Code
# AFE                           NaN  Africa Eastern and Southern  320589.996671
# AFG                    Low income                  Afghanistan    6739.999771
# AFW                           NaN   Africa Western and Central  225169.999979
# AGO           Lower middle income                       Angola   21219.999313
# ALB           Upper middle income                      Albania    3539.999962
# ...                           ...                          ...            ...
# WSM           Lower middle income                        Samoa     209.999993
# YEM                    Low income                  Yemen, Rep.    8890.000343
# ZAF           Upper middle income                 South Africa   63189.998627
# ZMB                    Low income                       Zambia   12029.999733
# ZWE           Lower middle income                     Zimbabwe    9609.999657
#
# ...

# %%
#export as excel 
methane_clean.to_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Methane_CleanData_noregion.xlsx', index=False)
#export as csv
methane_clean.to_csv('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Excel/Methane_CleanData_noregion.csv')
