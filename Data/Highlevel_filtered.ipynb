# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Carbon_CleanData.xlsx')

# %%
df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            AFE                         NaN                  NaN
# 1            AFG                  South Asia           Low income
# 2            AFW                         NaN                  NaN
# 3            AGO          Sub-Saharan Africa  Lower middle income
# 4            ALB       Europe & Central Asia  Upper middle income
# ..           ...                         ...                  ...
# 228          WSM         East Asia & Pacific  Lower middle income
# 229          YEM  Middle East & North Africa           Low income
# 230          ZAF          Sub-Saharan Africa  Upper middle income
# 231          ZMB          Sub-Saharan Africa           Low income
# 232          ZWE          Sub-Saharan Africa  Lower middle income
#
#                     Country Name           1990           1991           1992  \
# 0    Africa Eastern and Southern  304354.882669  298735.435602  295090.000000
# ...

# %%
nan_values = df[df['Region'].isna()]
nan_values
# Out:
#     Country Code Region IncomeGroup  \
# 0            AFE    NaN         NaN
# 2            AFW    NaN         NaN
# 6            ARB    NaN         NaN
# 33           CEB    NaN         NaN
# 45           CSS    NaN         NaN
# 55           EAP    NaN         NaN
# 56           EAR    NaN         NaN
# 57           EAS    NaN         NaN
# 58           ECA    NaN         NaN
# 59           ECS    NaN         NaN
# 62           EMU    NaN         NaN
# 66           EUU    NaN         NaN
# 67           FCS    NaN         NaN
# 83           HIC    NaN         NaN
# 85           HPC    NaN         NaN
# 89           IBD    NaN         NaN
# 90           IBT    NaN         NaN
# 91           IDA    NaN         NaN
# 92           IDB    NaN         NaN
# 94           IDX    NaN         NaN
# 113          LAC    NaN         NaN
# 119          LCN    NaN         NaN
# 120          LDC    NaN         NaN
# 121          LIC    NaN         NaN
# 124          LMC    NaN         NaN
# ...

# %%
#IBRD & IDA & incomes  keep high level regions in country name
no_income = df.drop(df.index [[56,83,85,89,90,91,92,94,120,121,124,125,127,137,159,168,173,219]])
no_income
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            AFE                         NaN                  NaN
# 1            AFG                  South Asia           Low income
# 2            AFW                         NaN                  NaN
# 3            AGO          Sub-Saharan Africa  Lower middle income
# 4            ALB       Europe & Central Asia  Upper middle income
# ..           ...                         ...                  ...
# 228          WSM         East Asia & Pacific  Lower middle income
# 229          YEM  Middle East & North Africa           Low income
# 230          ZAF          Sub-Saharan Africa  Upper middle income
# 231          ZMB          Sub-Saharan Africa           Low income
# 232          ZWE          Sub-Saharan Africa  Lower middle income
#
#                     Country Name           1990           1991           1992  \
# 0    Africa Eastern and Southern  304354.882669  298735.435602  295090.000000
# ...

# %%
country_name = no_income[no_income['Region'].isna()]
country_name
# Out:
#     Country Code Region IncomeGroup  \
# 0            AFE    NaN         NaN
# 2            AFW    NaN         NaN
# 6            ARB    NaN         NaN
# 33           CEB    NaN         NaN
# 45           CSS    NaN         NaN
# 55           EAP    NaN         NaN
# 57           EAS    NaN         NaN
# 58           ECA    NaN         NaN
# 59           ECS    NaN         NaN
# 62           EMU    NaN         NaN
# 66           EUU    NaN         NaN
# 67           FCS    NaN         NaN
# 113          LAC    NaN         NaN
# 119          LCN    NaN         NaN
# 135          MEA    NaN         NaN
# 142          MNA    NaN         NaN
# 150          NAC    NaN         NaN
# 161          OSS    NaN         NaN
# 172          PSS    NaN         NaN
# 178          SAS    NaN         NaN
# 188          SSA    NaN         NaN
# 190          SSF    NaN         NaN
# 191          SST    NaN         NaN
# 201          TEA    NaN         NaN
# 202          TEC    NaN         NaN
# ...

# %%
country_name = country_name.drop(['Country Code','Region','IncomeGroup'], axis=1)
country_name
# Out:
#                                           Country Name          1990  \
# 0                          Africa Eastern and Southern  3.043549e+05
# 2                           Africa Western and Central  9.792580e+04
# 6                                           Arab World  6.361290e+05
# 33                      Central Europe and the Baltics  9.890300e+05
# 45                              Caribbean small states  2.758000e+04
# 55         East Asia & Pacific (excluding high income)  2.672062e+06
# 57                                 East Asia & Pacific  4.510719e+06
# 58       Europe & Central Asia (excluding high income)  3.845992e+06
# 59                               Europe & Central Asia  7.975648e+06
# 62                                           Euro area  2.622740e+06
# 66                                      European Union  3.562590e+06
# 67            Fragile and conflict affected situations  4.408469e+05
# 113  Latin America & Caribbean (excluding high income)  7.345400e+05
# ...

# %%
#filtered_df = df.loc[df['C'] == 'Y']

# %%
#export as excel 
country_name.to_excel('/Users/vickylynnmauldin/Desktop/personal-repo/global-carbon-and-methane-emissions/Data/Carbon_Highlevel_Country.xlsx', index=False)

# %%
nan_values
# Out:
#     Country Code Region IncomeGroup  \
# 0            AFE    NaN         NaN
# 2            AFW    NaN         NaN
# 6            ARB    NaN         NaN
# 33           CEB    NaN         NaN
# 45           CSS    NaN         NaN
# 55           EAP    NaN         NaN
# 56           EAR    NaN         NaN
# 57           EAS    NaN         NaN
# 58           ECA    NaN         NaN
# 59           ECS    NaN         NaN
# 62           EMU    NaN         NaN
# 67           EUU    NaN         NaN
# 68           FCS    NaN         NaN
# 85           HIC    NaN         NaN
# 87           HPC    NaN         NaN
# 91           IBD    NaN         NaN
# 92           IBT    NaN         NaN
# 93           IDA    NaN         NaN
# 94           IDB    NaN         NaN
# 96           IDX    NaN         NaN
# 115          LAC    NaN         NaN
# 121          LCN    NaN         NaN
# 122          LDC    NaN         NaN
# 123          LIC    NaN         NaN
# 126          LMC    NaN         NaN
# ...
